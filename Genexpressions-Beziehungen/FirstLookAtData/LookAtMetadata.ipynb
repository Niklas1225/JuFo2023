# %%
#imports
import numpy as np
import pandas as pd

# %% [markdown]
# The entire data with all RNA sequences cannot be displayed yet because the file is too large to upload to GitHub. Therefore, the metadata of the patients are considered here first.

# %%
#load data
df = pd.read_csv("./data/cell_metadata.csv")

# %%
#Look at data
df.columns
# Out:
# Index(['specimen_name', 'sample_name', 'donor_sex_label',
#        'external_donor_name_label', 'species_label', 'age_label',
#        'region_label', 'cortical_layer_label', 'full_genotype_label', 'QCpass',
#        'cluster_label', 'cluster_confidence', 'subclass_label',
#        'subclass_confidence', 'class_label', 'class_confidence', 'GA_QCpass',
#        'GA_cluster_label', 'GA_subclass_label', 'GA_neighborhood_label',
#        'CA_QCpass', 'CA_cluster_label', 'CA_subclass_label',
#        'CA_neighborhood_label', 'cluster_color', 'cluster_order',
#        'subclass_color', 'subclass_order', 'class_color', 'class_order',
#        'GA_cluster_color', 'GA_cluster_order', 'GA_subclass_color',
#        'GA_subclass_order', 'CA_cluster_color', 'CA_cluster_order',
#        'CA_subclass_color', 'CA_subclass_order', 'cell_type_accession_label'],
#       dtype='object')

# %%
#Show one Example
df.iloc[0]
# Out:
# specimen_name                AAACCCACAACTCATG-LKTX_191204_01_A01-1156636525
# sample_name                  AAACCCACAACTCATG-LKTX_191204_01_A01-1156636525
# donor_sex_label                                                           M
# external_donor_name_label                                        H18.30.002
# species_label                                                  Homo Sapiens
# age_label                                                            50 yrs
# region_label                                                            MTG
# cortical_layer_label                                                    all
# full_genotype_label                                                     NaN
# QCpass                                                                 True
# cluster_label                                                        Pax6_1
# cluster_confidence                                                 0.999995
# ...

# %%
#Look at the whole Data
df
# Out:
#                                          specimen_name  \
# 0       AAACCCACAACTCATG-LKTX_191204_01_A01-1156636525
# 1       AAACCCACAATAGTAG-LKTX_191204_01_A01-1156636525
# 2       AAACCCACACGGTGTC-LKTX_191204_01_A01-1156636525
# 3       AAACCCACACTCTGCT-LKTX_191204_01_A01-1156636525
# 4       AAACCCACATCAGCAT-LKTX_191204_01_A01-1156636525
# ...                                                ...
# 166863  TTGGGCGTCCTCTTTC-L8TX_200107_01_A09-1156636575
# 166864  TTGGGCGTCGTGGGTC-L8TX_200107_01_A09-1156636575
# 166865  TTGGGTAGTTTGGGAG-L8TX_200107_01_A09-1156636575
# 166866  TTGTGGAAGTGGACGT-L8TX_200107_01_A09-1156636575
# 166867  TTTCGATAGGAATTAC-L8TX_200107_01_A09-1156636575
#
#                                            sample_name donor_sex_label  \
# 0       AAACCCACAACTCATG-LKTX_191204_01_A01-1156636525               M
# 1       AAACCCACAATAGTAG-LKTX_191204_01_A01-1156636525               M
# 2       AAACCCACACGGTGTC-LKTX_191204_01_A01-1156636525               M
# ...
